# %%
#1.Find the error in the following Python code:

for i in range(5):
 print(i)
#Indentation, sybol (:) was missing at the end of for loop.
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = 5
print(a + b)
# Removed quotes from b variable to make b as integer.
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
 return a + b
#Indentation, symbol (:) was missing at the end of function definition.

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
#5.Find the error in the following Python code:
print ("Hello, World!")
#paranthesis was missed both the sides.
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 1
#division by zero error

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = 25
print(f"Name: {name}, Age: {age}")
#name 'name' is not defined
#quote was missed before Age variable
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, 1):
    print(i)
#Since the step value is negative, the sequence will decrement. However, the start value (1) is less than the stop value (10), so the loop will not execute at all
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#9. Find the error in the following Python code:
x = 5
if x == 5:
    print("x is 5")
#x is 10, the condition is False, and the print statement will not be executed.
# Out:
# x is 5

# %%
#10. Identify the error in the following function definition:

def greet(name):
    print(f"Hello, {name}")
greet("Dilli")
greet(45000)
#Symbol (:) was missing at the end of function.
# Out:
# Hello, Dilli
# Hello, 45000
